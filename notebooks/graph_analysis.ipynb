# %%
from src.data.graph_analyzer import GraphAnalyzer
import networkx as nx

# %%
# import graph gml
file_path = 'data/processed/wikipedia_Amiga_CD32_games.gml'
file_path = 'data/processed/graph_jazz_collab.gml'

G = nx.read_gml(file_path)

# %%
graph_analyzer = GraphAnalyzer(G)

# %%
graph_analyzer.plot_degree_vs_avg_degree('Title', plot_randomized=True)
graph_analyzer.plot_log_log_probability_density('Title')

# %%
graph_analyzer.plot_centralities()

# %%
graph_analyzer.plot_centralities_comparison()

# %%
graph_analyzer.plot_centralities_comparison_randomized()
